# %%
from model.tol_falhas import TolFalhas

tol = TolFalhas()

# %%
sensor = ['temp', 'umid']
urls = ['https://www.adrianobailao.com.br/mvc_simulador/dados/base_de_dados/topico_sc5_temperature_20240315_0644.csv',
        'https://www.adrianobailao.com.br/mvc_simulador/dados/base_de_dados/topico_sc5_humidity_20240315_0644.csv']

# %%
dict_url = tol.dict_urls(sensor, urls)
print(dict_url)
# Out:
# {'temp': 'https://www.adrianobailao.com.br/mvc_simulador/dados/base_de_dados/topico_sc5_temperature_20240315_0644.csv', 'umid': 'https://www.adrianobailao.com.br/mvc_simulador/dados/base_de_dados/topico_sc5_humidity_20240315_0644.csv'}

# %%
df = tol.request_data(dict_url)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df = tol.request_data(dict_url)
#
# AttributeError: 'TolFalhas' object has no attribute 'request_data'

# %%
from model.tol_falhas import TolFalhas
import pandas as pd
import requests
from io import StringIO

sensor = ['temp', 'umid']
urls = ['https://www.adrianobailao.com.br/mvc_simulador/dados/base_de_dados/topico_sc5_temperature_20240315_0644.csv',
        'https://www.adrianobailao.com.br/mvc_simulador/dados/base_de_dados/topico_sc5_humidity_20240315_0644.csv']

tol = TolFalhas()
dict_urls = tol.dict_urls(sensor, urls)

df = tol.request_data(dict_urls)
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 13
#      10 tol = TolFalhas()
#      11 dict_urls = tol.dict_urls(sensor, urls)
# ---> 13 df = tol.request_data(dict_urls)
#      14 print(df)
#
# AttributeError: 'TolFalhas' object has no attribute 'request_data'

# %%
tol = TolFalhas()

# %%
tol.request_data(dict_urls)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 tol.request_data(dict_urls)
#
# AttributeError: 'TolFalhas' object has no attribute 'request_data'

# %%
from model.tol_falhas import TolFalhas
import inspect, sys

print(TolFalhas.__module__)                 # nome do módulo
modname = TolFalhas.__module__
mod = sys.modules[modname]
print(getattr(mod, "__file__", "(sem __file__)"))  # caminho do arquivo importado
print(inspect.getsource(TolFalhas))
# Out:
# model.tol_falhas
# /home/crdamke/Documentos/Python/app/app_falhas/model/tol_falhas.py
# class TolFalhas:
#     def __init__(self):
#         pass
#
#     '''
#     Dicionarios de sensores e urls em um único dicionário
#     '''
#     def dict_urls(self, sensor: list, url: list):
#         files_url = {}
#         for i in range(len(sensor)):
#             files_url[sensor[i]] = url[i]
#         return files_url
#
#     def request_data(self, dict_urls: dict):
#         headers = {
#             'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
#             }
#         data_frames = {}
#         for key, url in dict_urls.items():
#             print(f"Downloading data for {key} from {url}")
#             response = requests.get(url, headers=headers, timeout=30)
#             response.raise_for_status() # Checa se houve algum erro na requisição
#             if response.status_code == 200:
# ...

# %%
print(TolFalhas)
# Out:
# <class 'model.tol_falhas.TolFalhas'>
